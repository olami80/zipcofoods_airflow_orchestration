# %%
# Installing Neccesarry Packages

# # pandas, azure-storage-blob, dotenv

# !pip install pandas azure-storage-blob dotenv
# Out:
# Requirement already satisfied: pandas in c:\users\olalekan\anaconda3\lib\site-packages (2.2.2)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [67 lines of output]
#       C:\Users\OLALEKAN\anaconda3\Lib\site-packages\setuptools\__init__.py:81: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#       !!
#
#               ********************************************************************************
#               Requirements should be satisfied by a PEP 517 installer.
#               If you are using pip, you can try `pip install --use-pep517`.
#               ********************************************************************************
#
#       !!
#         dist.fetch_build_eggs(dist.setup_requires)
#         error: subprocess-exited-with-error
#
#         × python setup.py egg_info did not run successfully.
#         │ exit code: 1
#         ╰─> [1 lines of output]
#             ERROR: Can not execute `setup.py` since setuptools is not available in the build environment.
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: metadata-generation-failed
#
#       × Encountered error while generating package metadata.
#       ╰─> See above for output.
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for details.
#       Traceback (most recent call last):
#         File "C:\Users\OLALEKAN\anaconda3\Lib\site-packages\setuptools\installer.py", line 101, in _fetch_build_egg_no_warn
#           subprocess.check_call(cmd)
#         File "C:\Users\OLALEKAN\anaconda3\Lib\subprocess.py", line 413, in check_call
#           raise CalledProcessError(retcode, cmd)
#       subprocess.CalledProcessError: Command '['C:\\Users\\OLALEKAN\\anaconda3\\python.exe', '-m', 'pip', '--disable-pip-version-check', 'wheel', '--no-deps', '-w', 'C:\\Users\\OLALEKAN\\AppData\\Local\\Temp\\tmpnq546q2r', '--quiet', 'distribute']' returned non-zero exit status 1.
#
#       The above exception was the direct cause of the following exception:
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\OLALEKAN\AppData\Local\Temp\pip-install-qk2w_y8c\dotenv_3698ac41b27143018179e210100bbaca\setup.py", line 13, in <module>
#           setup(name='dotenv',
#         File "C:\Users\OLALEKAN\anaconda3\Lib\site-packages\setuptools\__init__.py", line 103, in setup
#           _install_setup_requires(attrs)
#         File "C:\Users\OLALEKAN\anaconda3\Lib\site-packages\setuptools\__init__.py", line 76, in _install_setup_requires
#           _fetch_build_eggs(dist)
#         File "C:\Users\OLALEKAN\anaconda3\Lib\site-packages\setuptools\__init__.py", line 81, in _fetch_build_eggs
#           dist.fetch_build_eggs(dist.setup_requires)
#         File "C:\Users\OLALEKAN\anaconda3\Lib\site-packages\setuptools\dist.py", line 640, in fetch_build_eggs
#           return _fetch_build_eggs(self, requires)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\OLALEKAN\anaconda3\Lib\site-packages\setuptools\installer.py", line 38, in _fetch_build_eggs
#           resolved_dists = pkg_resources.working_set.resolve(
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\OLALEKAN\anaconda3\Lib\site-packages\pkg_resources\__init__.py", line 798, in resolve
#           dist = self._resolve_dist(
#                  ^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\OLALEKAN\anaconda3\Lib\site-packages\pkg_resources\__init__.py", line 834, in _resolve_dist
#           dist = best[req.key] = env.best_match(
#                                  ^^^^^^^^^^^^^^^
#         File "C:\Users\OLALEKAN\anaconda3\Lib\site-packages\pkg_resources\__init__.py", line 1104, in best_match
#           return self.obtain(req, installer)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\OLALEKAN\anaconda3\Lib\site-packages\pkg_resources\__init__.py", line 1115, in obtain
#           return installer(requirement) if installer else None
#                  ^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\OLALEKAN\anaconda3\Lib\site-packages\setuptools\installer.py", line 103, in _fetch_build_egg_no_warn
#           raise DistutilsError(str(e)) from e
#       distutils.errors.DistutilsError: Command '['C:\\Users\\OLALEKAN\\anaconda3\\python.exe', '-m', 'pip', '--disable-pip-version-check', 'wheel', '--no-deps', '-w', 'C:\\Users\\OLALEKAN\\AppData\\Local\\Temp\\tmpnq546q2r', '--quiet', 'distribute']' returned non-zero exit status 1.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting azure-storage-blob
#   Downloading azure_storage_blob-12.23.1-py3-none-any.whl.metadata (26 kB)
# Collecting dotenv
#   Downloading dotenv-0.0.5.tar.gz (2.4 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'

# %%
# !pip install azure-storage-blob
# Out:
# Collecting azure-storage-blob
#   Using cached azure_storage_blob-12.23.1-py3-none-any.whl.metadata (26 kB)
# Collecting azure-core>=1.30.0 (from azure-storage-blob)
#   Downloading azure_core-1.31.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\olalekan\anaconda3\lib\site-packages (from azure-storage-blob) (42.0.5)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\olalekan\anaconda3\lib\site-packages (from azure-storage-blob) (4.11.0)
# Collecting isodate>=0.6.1 (from azure-storage-blob)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: requests>=2.21.0 in c:\users\olalekan\anaconda3\lib\site-packages (from azure-core>=1.30.0->azure-storage-blob) (2.32.2)
# Requirement already satisfied: six>=1.11.0 in c:\users\olalekan\appdata\roaming\python\python312\site-packages (from azure-core>=1.30.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\olalekan\anaconda3\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\olalekan\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\olalekan\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\olalekan\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\olalekan\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\olalekan\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2024.6.2)
# Downloading azure_storage_blob-12.23.1-py3-none-any.whl (405 kB)
#    ---------------------------------------- 0.0/405.6 kB ? eta -:--:--
#    ------ --------------------------------- 61.4/405.6 kB 1.6 MB/s eta 0:00:01
#    ------------ --------------------------- 122.9/405.6 kB 2.4 MB/s eta 0:00:01
#    ------------------------- -------------- 256.0/405.6 kB 2.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 358.4/405.6 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  399.4/405.6 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  399.4/405.6 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 405.6/405.6 kB 1.4 MB/s eta 0:00:00
# Downloading azure_core-1.31.0-py3-none-any.whl (197 kB)
#    ---------------------------------------- 0.0/197.4 kB ? eta -:--:--
#    ------------ --------------------------- 61.4/197.4 kB 3.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 174.1/197.4 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  194.6/197.4 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 197.4/197.4 kB 1.1 MB/s eta 0:00:00
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ---------------------------------------- 0.0/41.7 kB ? eta -:--:--
#    ---------------------------------------  41.0/41.7 kB ? eta -:--:--
#    ---------------------------------------  41.0/41.7 kB ? eta -:--:--
#    ---------------------------------------- 41.7/41.7 kB 403.6 kB/s eta 0:00:00
# Installing collected packages: isodate, azure-core, azure-storage-blob
# Successfully installed azure-core-1.31.0 azure-storage-blob-12.23.1 isodate-0.6.1

# %%
import azure.storage.blob

# %%
from azure.storage.blob import BlobServiceClient

# %%
# !pip install dotenv

# %%
# Importing Necessary Libraries

import pandas as pd
from dotenv import load_dotenv
import os

# %%
# Data Extraction

try:
  data = pd.read_csv('zipco_transaction.csv')
  print('Data Extracted Succesfully')
except Exception as e:
  print(f"An error occurred: {e}")
# Out:
# Data Extracted Succesfully

# %%
data.head()
# Out:
#                   Date      ProductName  Quantity  UnitPrice StoreLocation  \
# 0  2023-01-01 00:00:00     Vanilla Cake         2  12.532304         South
# 1  2023-01-01 01:00:00  Red Velvet Cake         1   7.083070         South
# 2  2023-01-01 02:00:00   Chocolate Cake         5   6.736064         North
# 3  2023-01-01 03:00:00      Carrot Cake         2   7.314823         North
# 4  2023-01-01 04:00:00  Pizza Pepperoni         1   7.577727          East
#
#    PaymentType  PromotionApplied Weather  Temperature StaffPerformanceRating  \
# 0         Cash              True   Rainy    20.654914                   Poor
# 1         Cash             False   Rainy    23.549497                Average
# 2         Cash              True   Rainy          NaN              Excellent
# 3         Cash             False  Cloudy    20.137483                   Poor
# 4  Credit Card              True  Cloudy    23.020987                   Good
#
#    ... DeliveryTime_min     OrderType      CustomerName  \
# 0  ...               30      In Store     William Adams
# 1  ...               33      In Store   Anthony Wiggins
# 2  ...               43   Phone Order       Ashley Duke
# 3  ...               32  Online Order    Brandon Taylor
# 4  ...               58      In Store  Brittany Watkins
#
#                                      CustomerAddress Customer_PhoneNumber  \
# 0           9851 David Green\r\nTonyaburgh, VA 02853    (916)427-7276x861
# 1      24682 Holly Stravenue\r\nMooreville, NH 13901         769.318.4373
# 2  10184 Washington Trace Apt. 679\r\nEast Brandi...         702.520.3286
# 3           87194 Jeff Rue\r\nMitchellbury, CA 50463         622-527-9530
# 4             850 Julia Groves\r\nHartview, WI 95954         759-517-8359
#
#                    CustomerEmail        Staff_Name              Staff_Email  \
# 0             lisa00@example.net      John Bridges    pdavidson@example.com
# 1  michellefernandez@example.com     Sarah Bentley     ajohnson@example.net
# 2      cooperwilliam@example.com  Connie Cervantes    michele29@example.net
# 3             fsilva@example.net   Jessica Stewart      xwilson@example.org
# 4       petersjoseph@example.net  Cheryl Carpenter  christine96@example.org
#
#   DayOfWeek TotalSales
# 0    Sunday  25.064608
# 1    Sunday   7.083070
# 2    Sunday  33.680321
# 3    Sunday  14.629647
# 4    Sunday   7.577727
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    1005 non-null   object
#  1   ProductName             1005 non-null   object
#  2   Quantity                1005 non-null   int64
#  3   UnitPrice               1005 non-null   float64
#  4   StoreLocation           1005 non-null   object
#  5   PaymentType             1005 non-null   object
#  6   PromotionApplied        1005 non-null   bool
#  7   Weather                 1005 non-null   object
#  8   Temperature             904 non-null    float64
#  9   StaffPerformanceRating  1005 non-null   object
#  10  CustomerFeedback        905 non-null    object
#  11  DeliveryTime_min        1005 non-null   int64
#  12  OrderType               1005 non-null   object
#  13  CustomerName            1005 non-null   object
#  14  CustomerAddress         1005 non-null   object
#  15  Customer_PhoneNumber    1005 non-null   object
#  16  CustomerEmail           904 non-null    object
#  17  Staff_Name              1005 non-null   object
#  18  Staff_Email             904 non-null    object
#  19  DayOfWeek               1005 non-null   object
#  20  TotalSales              1005 non-null   float64
# dtypes: bool(1), float64(3), int64(2), object(15)
# memory usage: 158.1+ KB
